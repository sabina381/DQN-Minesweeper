# %%
from train import Trainer
from config import CONFIG
import pickle
from pathlib import Path

# %%
# 파라미터를 출력한 txt 파일 생성
config_str = ""
for item in CONFIG.items():
    config_str += str(item) + "\n"

path = f"{CONFIG.PATH}/{CONFIG.FOLDER_NAME}/config.txt"
path = Path(path)
path.parent.mkdir(parents=True, exist_ok=True)

with open(path, "a") as f:
    f.write(config_str)

# %%
train = Trainer(FOLDER_NAME=CONFIG.FOLDER_NAME,
                PATH=CONFIG.PATH,
                EPISODES=CONFIG.EPISODES,
                VALID_EPISODES=CONFIG.VALID_EPISODES,
                LAG=CONFIG.LAG,
                MODEL_CRITERIA=CONFIG.MODEL_CRITERIA,
                UPDATE_TARGET_EVERY=CONFIG.UPDATE_TARGET_EVERY,
                PRINT_EVERY=CONFIG.PRINT_EVERY,
                SAVE_EVERY=CONFIG.SAVE_EVERY,
                VALID_EVERY=CONFIG.VALID_EVERY,
                TRAIN_START=CONFIG.TRAIN_START,
                LEARN_MIN=CONFIG.LEARN_MIN,
                LEARN_DECAY=CONFIG.LEARN_DECAY,
                LEARN_EPOCH=CONFIG.LEARN_EPOCH,
                # Environment
                GRIDWORLD_SIZE=CONFIG.GRIDWORLD_SIZE,
                NUM_MINE=CONFIG.NUM_MINE,
                REWARD_DICT=CONFIG.REWARD_DICT,
                DONE_DICT=CONFIG.DONE_DICT,
                COLOR_DICT=CONFIG.COLOR_DICT,
                FIRST_MINE=CONFIG.FIRST_MINE,
                # DQN_Agent
                STATE_TYPE=CONFIG.STATE_TYPE,
                EPSILON=CONFIG.EPSILON,
                EPSILON_DECAY=CONFIG.EPSILON_DECAY,
                EPSILON_MIN=CONFIG.EPSILON_MIN,
                BATCH_SIZE=CONFIG.BATCH_SIZE,
                GAMMA=CONFIG.GAMMA,
                MEM_SIZE=CONFIG.MEM_SIZE,
                LEARN_MAX=CONFIG.LEARN_MAX,
                CONV_UNITS=CONFIG.CONV_UNITS,
                DEVICE=CONFIG.DEVICE,
                LOSS_FUNC=CONFIG.LOSS_FUNC,
                OPTIMIZER=CONFIG.OPTIMIZER)
# Out:
# Reset train log lists.
# Reset valid log lists.
# Reset test log lists.

# %%
train.train()
# Out:
# Reset train log lists.
# Reset valid log lists.
# Reset test log lists.
# Train start
# /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/codes/dqn_agent.py:138: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:257.)
#   states = torch.tensor([sample[0] for sample in mini_batch], dtype=torch.float32).to(self.device).reshape(-1,1,self.nrow,self.ncol)
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_2500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.005 / Avg Reward: 0.229 / Avg cnt: 18.946 / Avg RPC: 0.229
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_2500.png
# Reset valid log lists.
#
# Create best model
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.005 / Avg Reward: 0.212 / Avg cnt: 20.026 / Avg RPC: 0.212
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_2500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_5000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.041 / Avg Reward: 0.327 / Avg cnt: 19.57 / Avg RPC: 0.327
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_5000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.014 / Avg Reward: 0.232 / Avg cnt: 18.829 / Avg RPC: 0.232
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_5000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_7500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.117 / Avg Reward: 0.453 / Avg cnt: 17.85 / Avg RPC: 0.453
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_7500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.053 / Avg Reward: 0.356 / Avg cnt: 17.775 / Avg RPC: 0.356
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_7500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_10000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.23 / Avg Reward: 0.549 / Avg cnt: 16.741 / Avg RPC: 0.549
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_10000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.108 / Avg Reward: 0.437 / Avg cnt: 17.463 / Avg RPC: 0.437
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_10000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_12500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.386 / Avg Reward: 0.665 / Avg cnt: 15.728 / Avg RPC: 0.665
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_12500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.255 / Avg Reward: 0.588 / Avg cnt: 15.526 / Avg RPC: 0.588
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_12500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_15000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.451 / Avg Reward: 0.678 / Avg cnt: 15.139 / Avg RPC: 0.678
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_15000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.396 / Avg Reward: 0.686 / Avg cnt: 14.525 / Avg RPC: 0.686
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_15000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_17500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.44 / Avg Reward: 0.673 / Avg cnt: 15.526 / Avg RPC: 0.673
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_17500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.38 / Avg Reward: 0.664 / Avg cnt: 15.235 / Avg RPC: 0.664
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_17500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_20000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.482 / Avg Reward: 0.705 / Avg cnt: 14.987 / Avg RPC: 0.705
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_20000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.448 / Avg Reward: 0.654 / Avg cnt: 15.587 / Avg RPC: 0.654
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_20000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_22500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.541 / Avg Reward: 0.72 / Avg cnt: 15.866 / Avg RPC: 0.72
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_22500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.544 / Avg Reward: 0.731 / Avg cnt: 15.238 / Avg RPC: 0.731
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_22500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_25000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.53 / Avg Reward: 0.711 / Avg cnt: 15.219 / Avg RPC: 0.711
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_25000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.544 / Avg Reward: 0.714 / Avg cnt: 15.522 / Avg RPC: 0.714
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_25000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_27500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.572 / Avg Reward: 0.716 / Avg cnt: 15.788 / Avg RPC: 0.716
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_27500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.532 / Avg Reward: 0.737 / Avg cnt: 15.265 / Avg RPC: 0.737
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_27500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_30000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.551 / Avg Reward: 0.744 / Avg cnt: 14.661 / Avg RPC: 0.744
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_30000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.516 / Avg Reward: 0.701 / Avg cnt: 15.66 / Avg RPC: 0.701
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_30000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_32500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.546 / Avg Reward: 0.695 / Avg cnt: 16.475 / Avg RPC: 0.695
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_32500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.555 / Avg Reward: 0.723 / Avg cnt: 15.717 / Avg RPC: 0.723
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_32500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_35000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.593 / Avg Reward: 0.749 / Avg cnt: 15.464 / Avg RPC: 0.749
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_35000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.582 / Avg Reward: 0.743 / Avg cnt: 14.515 / Avg RPC: 0.743
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_35000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_37500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.601 / Avg Reward: 0.781 / Avg cnt: 14.799 / Avg RPC: 0.781
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_37500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.588 / Avg Reward: 0.752 / Avg cnt: 15.223 / Avg RPC: 0.752
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_37500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_40000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.6 / Avg Reward: 0.763 / Avg cnt: 14.458 / Avg RPC: 0.763
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_40000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.613 / Avg Reward: 0.75 / Avg cnt: 16.041 / Avg RPC: 0.75
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_40000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_42500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.598 / Avg Reward: 0.763 / Avg cnt: 14.902 / Avg RPC: 0.763
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_42500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.622 / Avg Reward: 0.768 / Avg cnt: 15.342 / Avg RPC: 0.768
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_42500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_45000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.6 / Avg Reward: 0.744 / Avg cnt: 15.591 / Avg RPC: 0.744
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_45000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.604 / Avg Reward: 0.76 / Avg cnt: 15.071 / Avg RPC: 0.76
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_45000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_47500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.639 / Avg Reward: 0.781 / Avg cnt: 15.092 / Avg RPC: 0.781
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_47500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.618 / Avg Reward: 0.763 / Avg cnt: 15.503 / Avg RPC: 0.763
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_47500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_50000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.642 / Avg Reward: 0.778 / Avg cnt: 15.647 / Avg RPC: 0.778
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_50000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.585 / Avg Reward: 0.746 / Avg cnt: 15.064 / Avg RPC: 0.746
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_50000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_52500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.618 / Avg Reward: 0.751 / Avg cnt: 15.892 / Avg RPC: 0.751
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_52500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.638 / Avg Reward: 0.755 / Avg cnt: 15.535 / Avg RPC: 0.755
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_52500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_55000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.61 / Avg Reward: 0.745 / Avg cnt: 15.63 / Avg RPC: 0.745
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_55000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.637 / Avg Reward: 0.767 / Avg cnt: 15.523 / Avg RPC: 0.767
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_55000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_57500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.628 / Avg Reward: 0.77 / Avg cnt: 15.448 / Avg RPC: 0.77
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_57500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.624 / Avg Reward: 0.758 / Avg cnt: 15.624 / Avg RPC: 0.758
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_57500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_60000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.628 / Avg Reward: 0.784 / Avg cnt: 15.493 / Avg RPC: 0.784
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_60000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.638 / Avg Reward: 0.783 / Avg cnt: 15.59 / Avg RPC: 0.783
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_60000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_62500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.623 / Avg Reward: 0.758 / Avg cnt: 15.633 / Avg RPC: 0.758
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_62500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.647 / Avg Reward: 0.783 / Avg cnt: 15.179 / Avg RPC: 0.783
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_62500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_65000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.637 / Avg Reward: 0.764 / Avg cnt: 15.622 / Avg RPC: 0.764
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_65000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.61 / Avg Reward: 0.763 / Avg cnt: 14.976 / Avg RPC: 0.763
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_65000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_67500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.62 / Avg Reward: 0.756 / Avg cnt: 16.168 / Avg RPC: 0.756
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_67500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.63 / Avg Reward: 0.757 / Avg cnt: 15.018 / Avg RPC: 0.757
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_67500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_70000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.646 / Avg Reward: 0.773 / Avg cnt: 15.804 / Avg RPC: 0.773
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_70000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.634 / Avg Reward: 0.779 / Avg cnt: 15.412 / Avg RPC: 0.779
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_70000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_72500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.628 / Avg Reward: 0.753 / Avg cnt: 15.919 / Avg RPC: 0.753
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_72500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.633 / Avg Reward: 0.767 / Avg cnt: 15.073 / Avg RPC: 0.767
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_72500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_75000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.605 / Avg Reward: 0.762 / Avg cnt: 15.09 / Avg RPC: 0.762
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_75000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.624 / Avg Reward: 0.767 / Avg cnt: 15.456 / Avg RPC: 0.767
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_75000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_77500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.617 / Avg Reward: 0.758 / Avg cnt: 14.872 / Avg RPC: 0.758
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_77500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.629 / Avg Reward: 0.764 / Avg cnt: 15.93 / Avg RPC: 0.764
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_77500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_80000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.632 / Avg Reward: 0.74 / Avg cnt: 15.307 / Avg RPC: 0.74
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_80000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.635 / Avg Reward: 0.775 / Avg cnt: 15.65 / Avg RPC: 0.775
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_80000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_82500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.627 / Avg Reward: 0.783 / Avg cnt: 14.998 / Avg RPC: 0.783
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_82500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.62 / Avg Reward: 0.742 / Avg cnt: 15.978 / Avg RPC: 0.742
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_82500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_85000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.593 / Avg Reward: 0.723 / Avg cnt: 15.894 / Avg RPC: 0.723
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_85000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.621 / Avg Reward: 0.763 / Avg cnt: 15.445 / Avg RPC: 0.763
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_85000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_87500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.639 / Avg Reward: 0.767 / Avg cnt: 15.829 / Avg RPC: 0.767
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_87500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.62 / Avg Reward: 0.766 / Avg cnt: 15.029 / Avg RPC: 0.766
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_87500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_90000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.656 / Avg Reward: 0.781 / Avg cnt: 14.914 / Avg RPC: 0.781
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_90000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.618 / Avg Reward: 0.742 / Avg cnt: 15.859 / Avg RPC: 0.742
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_90000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_92500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.626 / Avg Reward: 0.741 / Avg cnt: 15.96 / Avg RPC: 0.741
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_92500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.63 / Avg Reward: 0.757 / Avg cnt: 14.889 / Avg RPC: 0.757
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_92500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_95000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.631 / Avg Reward: 0.759 / Avg cnt: 15.371 / Avg RPC: 0.759
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_95000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.641 / Avg Reward: 0.777 / Avg cnt: 14.466 / Avg RPC: 0.777
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_95000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_97500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.639 / Avg Reward: 0.776 / Avg cnt: 15.288 / Avg RPC: 0.776
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_97500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.641 / Avg Reward: 0.774 / Avg cnt: 14.375 / Avg RPC: 0.774
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_97500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_100000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.65 / Avg Reward: 0.77 / Avg cnt: 15.528 / Avg RPC: 0.77
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_100000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.651 / Avg Reward: 0.773 / Avg cnt: 15.524 / Avg RPC: 0.773
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_100000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_102500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.65 / Avg Reward: 0.764 / Avg cnt: 15.277 / Avg RPC: 0.764
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_102500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.664 / Avg Reward: 0.793 / Avg cnt: 15.159 / Avg RPC: 0.793
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_102500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_105000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.608 / Avg Reward: 0.762 / Avg cnt: 14.956 / Avg RPC: 0.762
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_105000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.662 / Avg Reward: 0.785 / Avg cnt: 15.449 / Avg RPC: 0.785
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_105000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_107500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.64 / Avg Reward: 0.776 / Avg cnt: 16.013 / Avg RPC: 0.776
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_107500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.671 / Avg Reward: 0.799 / Avg cnt: 15.675 / Avg RPC: 0.799
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_107500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_110000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.639 / Avg Reward: 0.754 / Avg cnt: 16.404 / Avg RPC: 0.754
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_110000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.639 / Avg Reward: 0.748 / Avg cnt: 15.411 / Avg RPC: 0.748
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_110000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_112500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.665 / Avg Reward: 0.778 / Avg cnt: 16.634 / Avg RPC: 0.778
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_112500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.648 / Avg Reward: 0.751 / Avg cnt: 15.686 / Avg RPC: 0.751
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_112500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_115000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.63 / Avg Reward: 0.759 / Avg cnt: 15.302 / Avg RPC: 0.759
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_115000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.635 / Avg Reward: 0.756 / Avg cnt: 16.349 / Avg RPC: 0.756
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_115000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_117500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.633 / Avg Reward: 0.77 / Avg cnt: 14.874 / Avg RPC: 0.77
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_117500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.645 / Avg Reward: 0.771 / Avg cnt: 14.718 / Avg RPC: 0.771
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_117500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_120000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.683 / Avg Reward: 0.799 / Avg cnt: 15.462 / Avg RPC: 0.799
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_120000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.637 / Avg Reward: 0.767 / Avg cnt: 15.287 / Avg RPC: 0.767
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_120000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_122500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.687 / Avg Reward: 0.791 / Avg cnt: 16.414 / Avg RPC: 0.791
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_122500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.675 / Avg Reward: 0.798 / Avg cnt: 15.678 / Avg RPC: 0.798
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_122500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_125000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.65 / Avg Reward: 0.766 / Avg cnt: 15.629 / Avg RPC: 0.766
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_125000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.629 / Avg Reward: 0.77 / Avg cnt: 15.546 / Avg RPC: 0.77
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_125000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_127500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.679 / Avg Reward: 0.786 / Avg cnt: 15.5 / Avg RPC: 0.786
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_127500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.668 / Avg Reward: 0.794 / Avg cnt: 15.772 / Avg RPC: 0.794
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_127500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_130000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.671 / Avg Reward: 0.799 / Avg cnt: 14.364 / Avg RPC: 0.799
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_130000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.676 / Avg Reward: 0.805 / Avg cnt: 15.243 / Avg RPC: 0.805
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_130000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_132500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.682 / Avg Reward: 0.797 / Avg cnt: 15.119 / Avg RPC: 0.797
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_132500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.656 / Avg Reward: 0.789 / Avg cnt: 15.278 / Avg RPC: 0.789
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_132500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_135000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.662 / Avg Reward: 0.778 / Avg cnt: 15.191 / Avg RPC: 0.778
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_135000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.656 / Avg Reward: 0.781 / Avg cnt: 14.371 / Avg RPC: 0.781
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_135000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_137500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.669 / Avg Reward: 0.781 / Avg cnt: 14.772 / Avg RPC: 0.781
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_137500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.687 / Avg Reward: 0.803 / Avg cnt: 15.168 / Avg RPC: 0.803
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_137500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_140000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.653 / Avg Reward: 0.789 / Avg cnt: 14.804 / Avg RPC: 0.789
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_140000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.657 / Avg Reward: 0.797 / Avg cnt: 14.273 / Avg RPC: 0.797
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_140000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_142500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.694 / Avg Reward: 0.81 / Avg cnt: 14.833 / Avg RPC: 0.81
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_142500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.669 / Avg Reward: 0.79 / Avg cnt: 14.425 / Avg RPC: 0.79
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_142500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_145000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.664 / Avg Reward: 0.8 / Avg cnt: 14.844 / Avg RPC: 0.8
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_145000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.677 / Avg Reward: 0.799 / Avg cnt: 14.715 / Avg RPC: 0.799
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_145000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_147500.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.675 / Avg Reward: 0.8 / Avg cnt: 15.004 / Avg RPC: 0.8
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_147500.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.675 / Avg Reward: 0.803 / Avg cnt: 14.855 / Avg RPC: 0.803
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_147500.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/train_150000.png
# === valid ===
# Start valid - latest model
# Reset valid log lists.
# Valid latest model completed. Avg win rate: 0.736 / Avg Reward: 0.814 / Avg cnt: 16.345 / Avg RPC: 0.814
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_latest_150000.png
# Reset valid log lists.
#
# Model loaded from '/Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/models/best.pkl'
# Valid best model completed. Avg win rate: 0.698 / Avg Reward: 0.808 / Avg cnt: 15.391 / Avg RPC: 0.808
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/game_imgs/valid_best_150000.png
# ==============================
# Save image at /Users/seungyeonlee/Documents/GitHub/DQN-Minesweeper/dqn_260209/graphs/valid_1000.png
# Train completed. total avg win rate: 0.587
