# %%
from environment import Environment
from config import CONFIG

# %%
env = Environment(gridworld_size=CONFIG.GRIDWORLD_SIZE,
                num_mine=CONFIG.NUM_MINE,
                reward_dict=CONFIG.REWARD_DICT,
                done_dict=CONFIG.DONE_DICT,
                color_dict=CONFIG.COLOR_DICT
                )

# %%
env.render_answer()
# Out:
# <style type="text/css">
# #T_0f3cf_row0_col0, #T_0f3cf_row0_col1, #T_0f3cf_row0_col2, #T_0f3cf_row1_col0, #T_0f3cf_row1_col2, #T_0f3cf_row2_col0, #T_0f3cf_row2_col1, #T_0f3cf_row2_col2, #T_0f3cf_row2_col3, #T_0f3cf_row2_col4, #T_0f3cf_row2_col5, #T_0f3cf_row2_col6, #T_0f3cf_row2_col7, #T_0f3cf_row2_col8, #T_0f3cf_row3_col3, #T_0f3cf_row3_col5, #T_0f3cf_row4_col2, #T_0f3cf_row5_col2, #T_0f3cf_row6_col2, #T_0f3cf_row6_col6, #T_0f3cf_row6_col7, #T_0f3cf_row6_col8, #T_0f3cf_row7_col0, #T_0f3cf_row7_col1, #T_0f3cf_row7_col3, #T_0f3cf_row7_col4, #T_0f3cf_row7_col5, #T_0f3cf_row7_col6, #T_0f3cf_row7_col8, #T_0f3cf_row8_col1, #T_0f3cf_row8_col6, #T_0f3cf_row8_col7, #T_0f3cf_row8_col8 {
#   color: skyblue;
# }
# ...

# %%
env.render(env.present_state)
# Out:
# <style type="text/css">
# ...

# %%
action = env._coord_to_idx(0,0)
next_state, reward, done, clear = env.step(action)
print(reward, done, clear)
env.render(env.present_state)
# Out:
# 1 False False
# <style type="text/css">
# ...

# %%
action = env._coord_to_idx(2,0)
next_state, reward, done, clear = env.step(action)
print(reward, done, clear)
env.render(env.present_state)
# Out:
# 1 False False
# <style type="text/css">
# ...

# %%
action = env._coord_to_idx(0,1)
next_state, reward, done, clear = env.step(action)
print(reward, done, clear)
env.render(env.present_state)
# Out:
# -1 False False
# <style type="text/css">
# ...

# %%
action = env._coord_to_idx(8,8)
next_state, reward, done, clear = env.step(action)
print(reward, done, clear)
env.render(env.present_state)
# Out:
# 0.3 False False
# <style type="text/css">
# ...

# %%
action = env._coord_to_idx(2,1)
next_state, reward, done, clear = env.step(action)
print(reward, done, clear)
env.render(env.present_state)
# Out:
# -1 True False
# <style type="text/css">
# ...
